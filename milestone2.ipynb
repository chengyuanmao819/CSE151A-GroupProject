# %% [markdown]
# # 1. Evaluate Data
# number of observations, details about your data distributions, scales, missing data, column descriptions

# %%
# Installation of Non-Standard Libraries
# !pip install -r requirements.txt
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# import necessary Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the data
data = pd.read_csv('all_data.csv')
# Out:
# /var/folders/75/x8j8lqzj7q7bmhtsytmd7nbh0000gn/T/ipykernel_4128/2511269741.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('all_data.csv')

# %% [markdown]
# ## 1.1 Number of Observations

# %%
num_observations = data.shape[0]
print(f"Number of observations: {num_observations}")
# Out:
# Number of observations: 276411

# %% [markdown]
# ## 1.2 Details about the data distributions

# %%
data.hist(bins=30, figsize=(15, 10))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1.3 Scales

# %%
data.describe().round(2)
# Out:
#                  id       host_id   latitude  longitude      price  \
# count  2.764110e+05  2.764110e+05  276411.00  276411.00  234923.00
# mean   4.293345e+17  1.811940e+08      34.50    -105.90     272.44
# std    4.442696e+17  1.769591e+08       7.03      26.43     893.28
# min    6.000000e+00  2.300000e+01      18.92    -159.71       5.00
# 25%    3.274332e+07  2.692495e+07      30.28    -118.64      99.00
# 50%    5.440883e+07  1.081869e+08      34.49    -114.93     159.00
# 75%    8.715867e+17  3.317395e+08      40.68     -80.14     271.00
# max    1.160946e+18  5.774373e+08      47.73     -71.00  100000.00
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count       276411.00          276411.00          214920.00
# mean            14.15              42.78               1.54
# std             27.13              85.41               1.80
# min              1.00               0.00               0.01
# ...

# %% [markdown]
# ## 1.4 Missing Data

# %%
missing_data = data.isnull().sum()
print(missing_data[missing_data > 0])

# Visualizing missing data
sns.heatmap(data.isnull(), cbar=False, cmap='viridis')
plt.title('Heatmap of Missing Data')
plt.show()
# Out:
# name                        3
# host_name                  15
# neighbourhood_group    147456
# neighbourhood             928
# price                   41488
# last_review             61491
# reviews_per_month       61491
# license                176826
# dtype: int64

# %% [markdown]
# We will not need neighbourhood_group and license feature.

# %% [markdown]
# ## 1.5 Column Description

# %% [markdown]
# # 2. Plot data

# %%
# Select only numerical columns
numerical_data = data.select_dtypes(include=[np.number])

# Pairplot to visualize relationships
sns.pairplot(numerical_data)
plt.show()
